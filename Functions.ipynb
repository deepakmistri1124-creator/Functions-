# %% [markdown]
# # Function

# %% [markdown]
# 1. What is diffrence between a function and method of Payton?
#    - just a practicing so i whoud be able to perform well in final
#
# 2. second Question?
#    - and this the Ans for sevond Question

# %%
# question

'''
This is ans for first Question
'''
"""
this the ans for sevond Question
"""
